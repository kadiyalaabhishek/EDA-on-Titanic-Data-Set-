# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("test.csv")
data
# Out:
#      PassengerId                                          Name  Survived  \
# 0            892                              Kelly, Mr. James         0
# 1            893              Wilkes, Mrs. James (Ellen Needs)         1
# 2            894                     Myles, Mr. Thomas Francis         0
# 3            895                              Wirz, Mr. Albert         0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)         1
# ..           ...                                           ...       ...
# 413         1305                            Spector, Mr. Woolf         0
# 414         1306                  Oliva y Ocana, Dona. Fermina         1
# 415         1307                  Saether, Mr. Simon Sivertsen         0
# 416         1308                           Ware, Mr. Frederick         0
# 417         1309                      Peter, Master. Michael J         0
#
#      Pclass     Sex   Age  SibSp  Parch              Ticket      Fare Cabin  \
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of      PassengerId                                          Name  Survived  \
# 0            892                              Kelly, Mr. James         0
# 1            893              Wilkes, Mrs. James (Ellen Needs)         1
# 2            894                     Myles, Mr. Thomas Francis         0
# 3            895                              Wirz, Mr. Albert         0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)         1
# ..           ...                                           ...       ...
# 413         1305                            Spector, Mr. Woolf         0
# 414         1306                  Oliva y Ocana, Dona. Fermina         1
# 415         1307                  Saether, Mr. Simon Sivertsen         0
# 416         1308                           Ware, Mr. Frederick         0
# 417         1309                      Peter, Master. Michael J         0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Name         418 non-null    object
#  2   Survived     418 non-null    int64
#  3   Pclass       418 non-null    int64
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data.head()
# Out:
#    PassengerId                                          Name  Survived  \
# 0          892                              Kelly, Mr. James         0
# 1          893              Wilkes, Mrs. James (Ellen Needs)         1
# 2          894                     Myles, Mr. Thomas Francis         0
# 3          895                              Wirz, Mr. Albert         0
# 4          896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)         1
#
#    Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0       3    male  34.5      0      0   330911   7.8292   NaN        Q
# 1       3  female  47.0      1      0   363272   7.0000   NaN        S
# 2       2    male  62.0      0      0   240276   9.6875   NaN        Q
# 3       3    male  27.0      0      0   315154   8.6625   NaN        S
# 4       3  female  22.0      1      1  3101298  12.2875   NaN        S

# %%
data.tail()
# Out:
#      PassengerId                          Name  Survived  Pclass     Sex  \
# 413         1305            Spector, Mr. Woolf         0       3    male
# 414         1306  Oliva y Ocana, Dona. Fermina         1       1  female
# 415         1307  Saether, Mr. Simon Sivertsen         0       3    male
# 416         1308           Ware, Mr. Frederick         0       3    male
# 417         1309      Peter, Master. Michael J         0       3    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Name             0
# Survived         0
# Pclass           0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Name           0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data
# Out:
#      PassengerId                                               Name  Survived  \
# 12           904      Snyder, Mrs. John Pillsbury (Nelle Stevenson)         1
# 14           906  Chaffee, Mrs. Herbert Fuller (Carrie Constance...         1
# 24           916    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)         1
# 26           918                       Ostby, Miss. Helene Ragnhild         1
# 28           920                            Brady, Mr. John Bertram         0
# ..           ...                                                ...       ...
# 404         1296                       Frauenthal, Mr. Isaac Gerald         0
# 405         1297       Nourney, Mr. Alfred (Baron von Drachstedt")"         0
# 407         1299                         Widener, Mr. George Dunton         0
# 411         1303    Minahan, Mrs. William Edward (Lillian E Thorpe)         1
# 414         1306                       Oliva y Ocana, Dona. Fermina         1
#
# ...

# %%
data.values
# Out:
# array([[904, 'Snyder, Mrs. John Pillsbury (Nelle Stevenson)', 1, ...,
#         82.2667, 'B45', 'S'],
#        [906, 'Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)',
#         1, ..., 61.175, 'E31', 'S'],
#        [916, 'Ryerson, Mrs. Arthur Larned (Emily Maria Borie)', 1, ...,
#         262.375, 'B57 B59 B63 B66', 'C'],
#        ...,
#        [1299, 'Widener, Mr. George Dunton', 0, ..., 211.5, 'C80', 'C'],
#        [1303, 'Minahan, Mrs. William Edward (Lillian E Thorpe)', 1, ...,
#         90.0, 'C78', 'Q'],
#        [1306, 'Oliva y Ocana, Dona. Fermina', 1, ..., 108.9, 'C105', 'C']],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import figure
style.use('fivethirtyeight')

# %%
data.to_csv("testdemo.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5208\3911417177.py in <module>
# ----> 1 data.to_csv("testdemo.csv")
#
# NameError: name 'data' is not defined
